# %%
with open('./lua/worlds.lua', 'r') as reader:
    print(reader.read())
# Out:
# -----------------------------------------------------------------------------------------
# -- Game worlds
# -----------------------------------------------------------------------------------------
# require('com.utils')
#
# local Worlds = {
#     ----------------------------------------------------
#     -- Test
#     ----------------------------------------------------
#     ['Test'] = {
#         evidenceRate = .4,
#         names = Set {'A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9', 'AA', 'AB', 'AC'},
#         loves = {
#             ['A1'] = Set {'A2', 'A3', 'A4'},
#             ['A2'] = Set {'A3', 'A4', 'A5'},
#             ['A3'] = Set {'A4', 'A5', 'A6'},
#             ['A4'] = Set {'A5', 'A6', 'A7'},
#             ['A5'] = Set {'A6', 'A7', 'A8'},
#             ['A6'] = Set {'A7', 'A8', 'A9'},
#             ['A7'] = Set {'A8', 'A9', 'AA'},
#             ['A8'] = Set {'A9', 'AA', 'AB'},
#             ['A9'] = Set {'AA', 'AB', 'AC'},
# ...

# %%
names = {
    "Family": [
        'Bart', 'Liza', 'Homer', 'Marge', 'Maggie'],
    "Relatives": [
        'Abraham', 'Selma', 'Patty'],
    "School": [
        'Milhouse', 'Skinner', 'Edna', 'Martin', 'Ralph', 'Nelson'],
    "Homer's friends": [
        'Barney', 'Moe', 'Lenny', 'Carl'],
    "Neighbours": [
        'Flanders', 'Todd', 'Rod'],
    "Citizens": [
        'Burns', 'Smithers', 'Wiggum', 'Snake', 'Apu', 'Fat Tony'],
    "Celebrities": [
        'Krusty', 'Bob', 'Itchy', 'Scratchy'],
    "Extraterrestrials": [
        'Kang', 'Kodos']
}

# %%
names
# Out:
# {'Family': ['Bart', 'Liza', 'Homer', 'Marge', 'Maggie'],
#  'Relatives': ['Abraham', 'Selma', 'Patty'],
#  'School': ['Milhouse', 'Skinner', 'Edna', 'Martin', 'Ralph', 'Nelson'],
#  "Homer's friends": ['Barney', 'Moe', 'Lenny', 'Carl'],
#  'Neighbours': ['Flanders', 'Todd', 'Rod'],
#  'Citizens': ['Burns', 'Smithers', 'Wiggum', 'Snake', 'Apu', 'Fat Tony'],
#  'Celebrities': ['Krusty', 'Bob', 'Itchy', 'Scratchy'],
#  'Extraterrestrials': ['Kang', 'Kodos']}

# %%
loves = {
    # Family
    'Homer':  ['Bart', 'Liza', 'Marge', 'Maggie', 'Abraham', 'Moe', 'Apu', 'Barney', 'Carl', 'Lenny'],
    'Marge':  ['Bart', 'Liza', 'Homer', 'Maggie', 'Selma', 'Patty', 'Nelson', 'Snake', 'Apu'],
    'Bart':   ['Marge', 'Homer', 'Liza', 'Maggie', 'Krusty', 'Milhouse', 'Itchy', 'Scratchy', 'Fat Tony'],
    'Liza':   ['Marge', 'Homer', 'Bart', 'Maggie', 'Abraham', 'Krusty', 'Itchy', 'Scratchy', 'Nelson', 'Edna', 'Skinner'],
    'Maggie': ['Marge', 'Homer', 'Bart', 'Liza', 'Krusty', 'Itchy', 'Scratchy'],
    
    # Relatives
    'Abraham': ['Liza', 'Homer', 'Maggie'],
    'Selma':   ['Patty', 'Marge', 'Maggie', 'Bob'],
    'Patty':   ['Selma', 'Marge', 'Maggie', 'Skinner'],

    # School
    'Skinner': ['Edna', 'Patty', 'Liza', 'Martin'],
    'Edna':    ['Skinner', 'Liza', 'Flanders', 'Martin'],
    'Milhouse':['Bart', 'Krusty', 'Itchy', 'Scratchy', 'Liza'],
    'Martin':  ['Skinner', 'Liza', 'Edna', 'Krusty', 'Itchy', 'Scratchy'],
    'Ralph':   ['Wiggum', 'Skinner', 'Liza', 'Edna', 'Krusty', 'Itchy', 'Scratchy'],
    'Nelson':  ['Itchy', 'Scratchy', 'Marge', 'Krusty', 'Liza', 'Snake', 'Fat Tony'],
    'Barney':  ['Homer', 'Moe', 'Carl', 'Lenny', 'Marge'],    

    # Homer's friends
    'Moe':   ['Homer', 'Barney', 'Carl', 'Lenny', 'Marge'],
    'Lenny': ['Homer', 'Barney', 'Moe', 'Carl'],
    'Carl':  ['Homer', 'Barney', 'Moe', 'Lenny'],

    # Neighbours
    'Flanders': ['Todd', 'Rod', 'Homer', 'Bart', 'Liza', 'Marge', 'Maggie', 'Edna', 'Burns'],
    'Todd':     ['Flanders', 'Rod', 'Krusty', 'Itchy', 'Scratchy'],
    'Rod':      ['Flanders', 'Todd', 'Krusty', 'Itchy', 'Scratchy'],

    # Citizens
    'Burns':    ['Bart', 'Flanders', 'Smithers'],
    'Smithers': ['Burns'],
    'Wiggum':   ['Ralph'],
    'Apu':      ['Homer', 'Marge', 'Liza'],
    'Snake':    ['Marge', 'Bart', 'Fat Tony'],
    'Fat Tony': ['Bart', 'Krusty', 'Snake'],
    
    # Celebrities
    'Krusty':   ['Liza', 'Bart', 'Itchy', 'Scratchy', 'Fat Tony'],
    'Itchy':    ['Krusty'],
    'Bob':      ['Selma'],
    'Scratchy': ['Krusty'],
    
    # Extraterrestrials
    'Kang':  ['Kodos'],
    'Kodos': ['Kang'],    
}

# %%
loves
# Out:
# {'Homer': ['Bart',
#   'Liza',
#   'Marge',
#   'Maggie',
#   'Abraham',
#   'Moe',
#   'Apu',
#   'Barney',
#   'Carl',
#   'Lenny'],
#  'Marge': ['Bart',
#   'Liza',
#   'Homer',
#   'Maggie',
#   'Selma',
#   'Patty',
#   'Nelson',
#   'Snake',
#   'Apu'],
#  'Bart': ['Marge',
#   'Homer',
#   'Liza',
#   'Maggie',
#   'Krusty',
#   'Milhouse',
#   'Itchy',
#   'Scratchy',
#   'Fat Tony'],
#  'Liza': ['Marge',
#   'Homer',
#   'Bart',
#   'Maggie',
#   'Abraham',
#   'Krusty',
#   'Itchy',
#   'Scratchy',
#   'Nelson',
#   'Edna',
#   'Skinner'],
#  'Maggie': ['Marge', 'Homer', 'Bart', 'Liza', 'Krusty', 'Itchy', 'Scratchy'],
#  'Abraham': ['Liza', 'Homer', 'Maggie'],
#  'Selma': ['Patty', 'Marge', 'Maggie', 'Bob'],
#  'Patty': ['Selma', 'Marge', 'Maggie', 'Skinner'],
#  'Skinner': ['Edna', 'Patty', 'Liza', 'Martin'],
#  'Edna': ['Skinner', 'Liza', 'Flanders', 'Martin'],
#  'Milhouse': ['Bart', 'Krusty', 'Itchy', 'Scratchy', 'Liza'],
# ...
